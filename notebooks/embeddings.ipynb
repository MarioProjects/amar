# %%
from src.helpers.ollama import OllamaHelper
from src.embeddings.types import OllamaEmbedding

# %%
VERBOSE = True
EMBEDDING_MODEL = "nomic-embed-text"

# %%
model_helper = OllamaHelper(VERBOSE)

# %%
model_helper.pull_ollama_model(EMBEDDING_MODEL)
# Out:
# Pulling the model: nomic-embed-text...
# Successfully pulled the model: nomic-embed-text

# %%
embedder = OllamaEmbedding(EMBEDDING_MODEL)

# %%
text = "hello world"
embedding = embedder.get_embedding(text)
print(f"Embedding for '{text}': {embedding}")
# Out:
# Embedding for 'hello world': [-0.2968343198299408, 0.38141337037086487, -3.0465781688690186, -0.23779863119125366, 0.13035672903060913, 1.2533608675003052, -0.9813257455825806, -0.5612908601760864, -0.48090171813964844, -1.8602449893951416, 0.33106473088264465, -0.3457537591457367, 0.3800168037414551, 1.9651384353637695, 0.6910353899002075, -1.578421711921692, 0.4049198627471924, -0.598836362361908, -0.9435840249061584, -0.262291818857193, -0.12768913805484772, -1.440139889717102, -0.574315071105957, 0.8609520196914673, 0.8464295864105225, 0.3668818175792694, -0.24451446533203125, 1.2439091205596924, -0.12892353534698486, -0.8309499621391296, -0.11979544162750244, -0.4962579011917114, 0.6981646418571472, 1.7154090404510498, 0.8235217332839966, -0.1228141337633133, 0.6974095702171326, 0.6686142683029175, -0.8819108009338379, -0.16098469495773315, 0.11189013719558716, -1.5072450637817383, -0.03278007730841637, -0.5646864175796509, 1.1270196437835693, -0.778722882270813, 0.2400436103343
# ...
